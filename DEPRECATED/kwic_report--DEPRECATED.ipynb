# %% [markdown]
# # KWIC Report
#
# This notebook uses the results from the `parse_resources.ipynb` notebook.
# The parse resources step pulls data from ArchivesSpace and creates a
# dataframe that was output to a CSV file.
# This notebook starts from the CSV file, but it could
# relatively easily be changed to take the previous dataframe
# as an input.
#
# ## Credit
#
# Developed by Ella Li, June 2024. Original code at https://github.com/jiaqili0803/ReConnect-ReCollect_Automation/tree/main/NEW%20-%20Term%20report
#
# ## Setup
#
# If continuing or adapting this code, you have likely already imported these libraries.
# We will use `pandas` for data processing, and `re` for text analysis. Since the data is gathered in the `parse_resources.ipynb` notebook there is not a need for additional parsing.

# %%
import pandas as pd
import re
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Functions
#
# Two functions provide for text processing. These rely on data previously
# parsed from EAD data in the `parse_resources.ipynb` notebook,
# and saved as `results.csv`.
#
# `match_terms()` pulls from the previously collected EAD data.
# Unlike the similar function in the visualization notebook (`match_visualize.ipynb`),
# this function matches terms, records the term in question, and
# keys that data to its textual context, specifically providing the
# title of the finding aid (generally a direct match to the collection name),
# provides a file ID (corresponding to the repository's unique ID for the EAD),
# and the "context" which is derived from the immediate surrounding text
# (the function looks for blank lines to determine paragraph breaks and provides the whole paragraph).
#
# `match_and_visualize()` takes a dataframe with the match data from the EADS,
# reshapes the matched data to consistently name columns,
# groups the rows based on the matched term,
# and it outputs a CSV file with a unique name based on a repository identifier
# provided by the user as an input to the function.

# %%
def match_terms(row, terms, columns):
    results = []
    for term in terms:
        for col in columns:
            if not isinstance(row[col], float):
                # Split the column into paragraphs Note: the str() conversion was provided to catch a datatype error
                paragraphs = str(row[col]).split('\n')
                # Loop through each paragraph
                for paragraph in paragraphs:
                    # Check if the term is in the current paragraph
                    if re.search(r'\b' + re.escape(term) + r'\b', paragraph, re.IGNORECASE):
                        # Split paragraph into sentences
                        sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', paragraph)
                        # Find the sentence containing the term
                        matched_sentence = next((sentence for sentence in sentences if re.search(r'\b' + re.escape(term) + r'\b', sentence, re.IGNORECASE)), paragraph)
                        results.append({
                            'Term': term,
                            'Occurrence (ead_ID)': row['ead_id'],
                            'Field': col, 
                            'Collection': row.get('titleproper', None),
                            'Context': matched_sentence  # Returning only the matched sentence
                        })
    return results

# %%
def match_and_visualize(df, name):
    # Match results
    results_df = pd.DataFrame([result for index, row in df.iterrows() for result in match_terms(row, terms, df.columns)])
    
    # Sort results by 'Term'
    sorted_results_df = results_df.sort_values(by='Term', ascending=True)
    
    # Show matched results
    print(f'Matched results for {name}')

    # Export to CSV without the index
    sorted_results_df.to_csv('matched_results_incontext_' + name + '.csv', index=False)
    return sorted_results_df

# %% [markdown]
# ## Provide Terms
#
# Terms of interest are supplied in a plain text file, with
# each term of interest on its own line.

# %%
# read in the txt file term list
term_list_file = 'terms_all.txt'

with open(term_list_file, 'r') as f:
    terms = [line.strip() for line in f]

# %%
print(f'Read term list from {term_list_file} and recorded {len(terms)} terms of interest.')
# Out:
# Read term list from terms_all.txt and recorded 104 terms of interest.

# %% [markdown]
# ## Provide EAD Data
#
# Create a dataframe using the `results.csv` from the `parse_resources.ipynb` notebook.

# %%
eads_df = pd.read_csv('results.csv', encoding='utf-8')

# %%
eads_df = eads_df.rename(columns={'eadid':'ead_id'})

# %%
eads_df.head()
# Out:
#    resource_id           ead_id  \
# 0         3011  umich-bhl-00138
# 1          267   umich-bhl-0052
# 2          996   umich-bhl-0142
# 3         2722  umich-bhl-03171
# 4         1051   umich-bhl-0336
#
#                                          titleproper  \
# 0                        the Ralph M. Hodnett papers
# 1  Bentley Historical Library publications. 1935-...
# 2                          the Frank C. Gates papers
# 3      Mike Wallace CBS 60 Minutes Papers, 1922-2007
# 4               Grant Kohn Goodman papers, 1943-1995
#
#                                             abstract  \
# 0                                                NaN
# 1  The Bentley Historical Library (BHL) houses th...
# 2  Frank C. Gates was a professor of botany at th...
# 3  Papers of Mike Wallace (1918-2012), broadcast ...
# 4  Grant K. Goodman was a student at the Universi...
#
#                                             language  \
# 0              The finding aid is written in English
# 1              The finding aid is written in English
# 2  The finding aid is written in <language encodi...
# 3              The finding aid is written in English
# 4              The finding aid is written in English
#
#                                         scopecontent  \
# 0  This collection consists of reminiscences (wri...
# 1  The PUBLICATIONS (3.7 linear feet) are divided...
# 2  The Frank C. Gates papers are dated from 1871-...
# 3  The Mike Wallace CBS/ <title render="italic">6...
# 4  The Grant K. Goodman collection documents the ...
#
#                                             bioghist  \
# 0  Ralph M. Hodnett was an officer in the U.S. Ar...
# 1  The origins of the Bentley Historical Library ...
# 2  Frank Caleb Gates was born on September 12, 18...
# 3  Mike Wallace was born Myron Leon Wallace on Ma...
# 4  Grant Kohn Goodman was born in 1924 in Clevela...
#
#                                             subjects  \
# 0           Soldiers; World War, 1914-1918; Soldiers
# 1                                                NaN
# 2  Bird watching.; Botany; Forests and forestry; ...
# 3  60 minutes (Television program); Television br...
# 4  World War, 1939-1945; World War, 1939-1945; Wo...
#
#                                      subjects_source  \
# 0                                  lcsh; lcsh; lctgm
# 1                                                NaN
# 2                              lcsh; lcsh; lcsh; aat
# 3  lcsh; lcsh; lcsh; lcsh; lcsh; lcsh; lcsh; lcsh...
# 4                                   lcsh; lcsh; lcsh
#
#                                           genreforms  \
# 0                             Diaries.; Photographs.
# 1  Annual reports.; Newsletters.; Bibliographies....
# 2          Lantern slides.; Photographs.; Postcards.
# 3       Photographs.; Sound recordings.; Videotapes.
# 4  Digital file formats.; Photographs.; Sound rec...
#
#                              genreforms_source            geognames  \
# 0                                  lcsh; gmgpc          Philippines
# 1  aat; aat; aat; aat; aat; aat; aat; aat; aat                  NaN
# 2                                aat; aat; aat  Philippines; Plants
# 3                                aat; aat; aat                  NaN
# 4                           aat; aat; aat; aat               Tokyo.
#
#   geognames_source                                          persnames  \
# 0             lcsh               Hodnett, Ralph M.; Hodnett, Ralph M.
# 1              NaN                                                NaN
# 2      lcsh; lctgm  Gates, Frank C. (Frank Caleb), 1887-1955; Gate...
# 3              NaN  Wallace, Mike, 1918-2012; Wallace, Mike, 1918-...
# 4             lcsh  Goodman, Grant Kohn, 1924-2014; Goodman, Grant...
#
#              persnames_source  \
# 0                lcnaf; lcnaf
# 1                         NaN
# 2         lcnaf; lcnaf; lcnaf
# 3  lcnaf; lcnaf; lcnaf; lcnaf
# 4                lcnaf; lcnaf
#
#                                            corpnames     corpnames_source  \
# 0                               United States. Army.                lcnaf
# 1  Bentley Historical Library.; Michigan Historic...  lcnaf; lcnaf; lcnaf
# 2                     University of the Philippines.                lcnaf
# 3                               CBS News.; CBS News.         lcnaf; lcnaf
# 4  United States. Army. Japanese Language School ...  lcnaf; lcnaf; lcnaf
#
#        famnames famnames_source
# 0  Oram family.           lcnaf
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN

# %% [markdown]
# ## Run the KWIC Report
#
# Use the functions to create the CSV with terms in context.
# To do this, run the `match_and_visualize()` function with
# the EAD dataframe and the name of the group that is being analyzed.
#
# To customize the report, provide a dataframe of your own
# and change your data name. In the example below,
# we use `Bentley` because the EAD data was retrieved from
# the Bentley Historical Library at the University of Michigan.

# %%
match_and_visualize(eads_df, 'Bentley')
# Out:
# Matched results for Bentley
#          Term Occurrence (ead_ID)         Field  \
# 140  Colonial      umich-bhl-8772      bioghist
# 63   Colonial    umich-bhl-851733      bioghist
# 145  Colonial      umich-bhl-8868  scopecontent
# 66   Colonial    umich-bhl-851764      abstract
# 90   Colonial     umich-bhl-85419  scopecontent
# ..        ...                 ...           ...
# 43      Types   umich-bhl-2014136      bioghist
# 73      Types     umich-bhl-85193  scopecontent
# 50      Types    umich-bhl-851285  scopecontent
# 180     Types      umich-bhl-9840  scopecontent
# 137     Types  umich-bhl-87265.25      bioghist
#
#                                             Collection  \
# 140      Luce Philippine Project interviews, 1975-1980
# 63                         Harry Burns Hutchins papers
# 145         Blanchard Family Papers, ca. 1835-ca. 2000
# 66                 George A. Malcolm papers, 1896-1965
# 90                 Owen A. Tomlinson papers, 1899-1920
# ..                                                 ...
# 43   University Herbarium (University of Michigan) ...
# 73                               Philip A. Hart Papers
# 50                               Thomas Francis Papers
# 180                  Charles W. Lane papers, 1935-1997
# 137  News and Information Services (University of M...
#
#                                                Context
# 140  In 1977 the University of Michigan Center for ...
# 63   Mary Hutchins was a member of many organizatio...
# 145  The Blanchard Family Papers will be of value t...
# 66   Correspondence, scrapbooks, printed reports, a...
# 90   Within the Photograph series will be found six...
# ..                                                 ...
# 43   The U-M Herbarium is also a leader in digitizi...
# 73   Hart himself and his staff had discarded certa...
# 50   Types of records in these unprocessed subserie...
# 180  The researcher will be interested in the varie...
# 137  News Service has continued to expand its media...
#
# [183 rows x 5 columns]
